# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dots = sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
dots = sns.load_dataset("dots")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.set_theme(style="ticks")
#Defining a color palette
p = sns.color_palette('rocket_r')
#plot lineplot
sns.relplot(data=dots,x="time",y="firing_rate",hue="coherence",size="choice",col="align", kind="line", size_order=["T1","T2"],
            palette= p, height=5, aspect=0.75,facet_kws=dict(sharex=False),
)

# %% [markdown]
# ## On Chilla Data

# %%
chilla = pd.read_csv('ChillaData.csv')
chilla.head()
# Out:
#       Timestamp  Gender  Location    Age  Qualification      field_of_study  \
# 0  1/4/22 18:41    Male  Pakistan  21-25      Bachelors         Enginnering
# 1  1/4/22 18:02    Male  Pakistan  26-30      Bachelors               CS/IT
# 2  1/4/22 18:08    Male  Pakistan  21-25  Pre-Bachelors               CS/IT
# 3  1/4/22 18:05  Female      East  26-30        Masters  Business/Economics
# 4  1/4/22 18:09  Female  Pakistan  46-60        Masters              Others
#
#          Purpose_for_chilla Experience  Age.1 What are you?  ... Weight  \
# 0     to boost my skill set          0   24.0     Unemplyed  ...   60.0
# 1     to boost my skill set          1   25.0       Student  ...   53.6
# 2     to boost my skill set          0   21.0       Student  ...   60.0
# 3  Switch my field of study        2.3   30.0       Student  ...   56.9
# 4                      Awen       10.1   46.4      Employed  ...   90.0
#
#    Height Glasses First line of code Programming language Marital Status  \
# ...

# %% [markdown]
# ## Changing Binary optionset data to Numeric data

# %%
field = chilla['field_of_study']
vaccinated = chilla['Vaccinated'].map({'Yes': 1, 'No': 0})
gender =chilla['Gender'].map({'Male': 1, 'Female': 0})
glasses = chilla['Glasses'].map({'Yes': 1, 'No': 0})
marital = chilla['Marital Status'].map({'Yes': 1, 'No': 0})
area = chilla['Area'].map({'Urbun': 1, 'Rural': 0})

# %% [markdown]
# ## Scatterplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")


# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="First line of code", y="Height",
                hue=gender, size=vaccinated,
                hue_order=gender, color='red',
                sizes=(1, 8), linewidth=0,
                data=chilla, ax=ax)
# Out:
# <AxesSubplot:xlabel='First line of code', ylabel='Height'>

# %% [markdown]
# ## Lineplot

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Plot the responses for different events and regions
sns.lineplot(x="Age", y="Weight",
             hue=area, style=gender,
             data=chilla)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Weight'>

# %% [markdown]
# ## Displot

# %%
import seaborn as sns

sns.displot(
    chilla, x="Age", col=area, row=gender,
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)
plt.figure(figsize=(18,6))

# %% [markdown]
# ## Lmplot

# %%
import seaborn as sns
sns.set_theme(style="ticks")



# Show the results of a linear regression within each dataset
sns.lmplot(x="Height", y="Weight", col="Age", hue="Age", data=chilla,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# ## Violinplot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=chilla, x="Age", y="Coding Hours", hue=gender,
               split=True, inner="quart", linewidth=1,
               )
sns.despine(left=True)

# %% [markdown]
# ## Jointplot

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")



sns.jointplot(data=chilla, x="Age", y="Height", color="#4CB391")

# %% [markdown]
# ## Histplot

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    chilla,
    x="Height", hue="Network",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([500, 1000, 2000, 5000, 10000])

# %% [markdown]
# ##  Boxplot and Stripplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")


# Plot the orbital period with horizontal boxes
sns.boxplot(x="Coding Hours", y="Location", data=chilla,
            whis=[0, 100], width=.6, palette="vlag")

# Add in points to show each observation
sns.stripplot(x="Coding Hours", y="Location", data=chilla,
              size=4, color=".3", linewidth=0)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)

# %% [markdown]
# ## Jointplot with kind="kde"

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")



sns.jointplot(data=chilla, y="Weight", x="Height",kind="kde", color="#4CB391")

# %% [markdown]
# ## Boxenplot

# %%
diamonds = sns.load_dataset("diamonds")
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")


Network_ranking = ["Ufone", "Zong", "Mobilink", "Telenor", "International"]

sns.boxenplot(x="Network", y="Weight",
              color="b", order=Network_ranking,
              scale="linear", data=chilla)
# Out:
# <AxesSubplot:xlabel='Network', ylabel='Weight'>

# %% [markdown]
# ## JointGrid and Scatterplot

# %%
import seaborn as sns
sns.set_theme(style="white", color_codes=True)


# Use JointGrid directly to draw a custom plot
g = sns.JointGrid(data=chilla, x="Weight", y="Height", space=0, ratio=17)
g.plot_joint(sns.scatterplot, size=gender, sizes=(30, 120),
             color="g", alpha=.6, legend=False)
g.plot_marginals(sns.rugplot, height=1, color="g", alpha=.6)

# %%
chilla = pd.read_csv('ChillaData.csv')
chilla.head(5)
# Out:
#       Timestamp  Gender  Location    Age Qualification field_of_study  \
# 0  1/4/22 18:05    Male  Pakistan  21-25     Bachelors          CS/IT
# 1  1/4/22 18:09  Female  Pakistan  46-60       Masters         Others
# 2  1/4/22 18:05    Male  Pakistan  41-45       Masters          CS/IT
# 3  1/4/22 18:05    Male      West  41-45       Masters          CS/IT
# 4  1/4/22 18:05  Female  Pakistan  41-45       Masters    Enginnering
#
#       Purpose_for_chilla Experience  Age1 What are you?  ... Weight   Height  \
# 0  to boost my skill set          0  90.0     Unemplyed  ...   90.0     1.40
# 1                   Awen       10.1  46.4      Employed  ...   90.0   158.00
# 2  to boost my skill set       20.5  44.8      Employed  ...   70.5     1.76
# 3  to boost my skill set         20  43.0      Employed  ...   82.5   182.50
# 4  to boost my skill set          4  43.0      Employed  ...   70.0  1615.00
#
#   Glasses First line of code Programming language Marital Status  \
# ...

# %% [markdown]
# ## KDE Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")

# Set up the figure
f, ax = plt.subplots(figsize=(16,16))
ax.set_aspect("equal")

# Draw a contour plot to represent each bivariate density
sns.kdeplot(
    data=chilla,
    y="Weight",
    x="Age1",
    hue=vaccinated,
    thresh=.1,
)
# Out:
# <AxesSubplot:xlabel='Age1', ylabel='Weight'>

# %% [markdown]
# ## Displot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Plot the distribution of clarity ratings, conditional on carat
sns.displot(
    data=chilla,
    x="Height", hue=glasses,
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %% [markdown]
# ## Facet grid

# %%
sns.set_theme()

# Generate an example radial datast
r = np.linspace(0, 10, num=100)
df = pd.DataFrame({'r': r, 'slow': r, 'medium': 2 * r, 'fast': 4 * r})

# Convert the dataframe to long-form or "tidy" format
df = pd.melt(df, id_vars=['r'], var_name='speed', value_name='theta')

# Set up a grid of axes with a polar projection
g = sns.FacetGrid(df, col="speed", hue="speed",
                  subplot_kws=dict(projection='polar'), height=4.5,
                  sharex=False, sharey=False, despine=False)

# Draw a scatterplot onto each axes in the grid
g.map(sns.scatterplot, "theta", "r")

# %% [markdown]
# ## Swarm Plot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid", palette="muted")


# Draw a categorical scatterplot to show each observation
ax = sns.swarmplot(data=chilla, x="Coding Hours", hue=gender, y="Qualification")
ax.set(ylabel="")
# Out:
# /Users/asadtariq/opt/anaconda3/envs/env-IDS2020/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/asadtariq/opt/anaconda3/envs/env-IDS2020/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 56.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# [Text(0, 0.5, '')]

# %% [markdown]
# ## Joint grid

# %%
import seaborn as sns
sns.set_theme(style="white")


g = sns.JointGrid(data=chilla, x="Height", y="Weight", space=0)
g.plot_joint(sns.kdeplot,
             fill=True, clip=((2200, 6800), (10, 25)),
             thresh=0, levels=100, cmap="rocket")
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)

# %% [markdown]
# ## Violinplot

# %%
import numpy as np
import seaborn as sns

sns.set_theme()

# Create a random dataset across several variables
rs = np.random.default_rng(0)
n, p = 40, 8
d = rs.normal(0, 2, (n, p))
d += np.log(np.arange(1, p + 1)) * -5 + 10

# Show each distribution with both violins and points
sns.violinplot(data=chilla, palette="light:g", inner="points", orient="h")
# Out:
# <AxesSubplot:>
