# %% [markdown]
# # Caldera

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Feature Extraction

# %%
from nfstream import NFStreamer

# %% [markdown]
# ### Clean Traffic

# %%
clean= pd.read_csv("/Users/asadtariq/Downloads/clean.csv",on_bad_lines='skip')
# Out:
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1232510215.py:1: DtypeWarning: Columns (71,72,85,86,90,91,95,97,101,111,113,114,115,117,121,133,135,140,160,166,174,196,197) have mixed types. Specify dtype option on import or set low_memory=False.
#   clean= pd.read_csv("/Users/asadtariq/Downloads/clean.csv",on_bad_lines='skip')

# %% [markdown]
# ### Malicious Traffic

# %%
malicious= pd.read_csv("/Users/asadtariq/Downloads/malicious 2.csv", on_bad_lines='skip')
malicious
# Out:
#                                                frame.bblog  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1          NaN
#                                             1          NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1          NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1          NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1          NaN
# ...                                                    ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1          NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1          NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1          NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1          NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1          NaN
#
#                                                frame.bblog.serial_nr  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                      0
#                                             1                      0
#             815 NaN NaN NaN NaN NaN NaN NaN 1                      0
#             219 NaN NaN NaN NaN NaN NaN NaN 1                      0
#             562 NaN NaN NaN NaN NaN NaN NaN 1                      0
# ...                                                              ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                      0
#             807 NaN NaN NaN NaN NaN NaN NaN 1                      0
#             218 NaN NaN NaN NaN NaN NaN NaN 1                      0
#             158 NaN NaN NaN NaN NaN NaN NaN 1                      0
#             66  NaN NaN NaN NaN NaN NaN NaN 1                      0
#
#                                                frame.bblog.ticks  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                NaN
#                                             1                NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1                NaN
# ...                                                          ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1                NaN
#
#                                                frame.cap_len  frame.cb_copy  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
#                                             1            NaN              0
#             815 NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
#             219 NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
#             562 NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
# ...                                                      ...            ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
#             807 NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
#             218 NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
#             158 NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
#             66  NaN NaN NaN NaN NaN NaN NaN 1            NaN              0
#
#                                               frame.cb_pen  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1         eth0
#                                             1         eth0
#             815 NaN NaN NaN NaN NaN NaN NaN 1         eth0
#             219 NaN NaN NaN NaN NaN NaN NaN 1         eth0
#             562 NaN NaN NaN NaN NaN NaN NaN 1         eth0
# ...                                                    ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1         eth0
#             807 NaN NaN NaN NaN NaN NaN NaN 1         eth0
#             218 NaN NaN NaN NaN NaN NaN NaN 1         eth0
#             158 NaN NaN NaN NaN NaN NaN NaN 1         eth0
#             66  NaN NaN NaN NaN NaN NaN NaN 1         eth0
#
#                                                frame.coloring_rule.name  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                       NaN
#                                             1                       NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                       NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                       NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1                       NaN
# ...                                                                 ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                       NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                       NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1                       NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1                       NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1                       NaN
#
#                                                frame.coloring_rule.string  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                          66
#                                             1                          66
#             815 NaN NaN NaN NaN NaN NaN NaN 1                         815
#             219 NaN NaN NaN NaN NaN NaN NaN 1                         219
#             562 NaN NaN NaN NaN NaN NaN NaN 1                         562
# ...                                                                   ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                          66
#             807 NaN NaN NaN NaN NaN NaN NaN 1                         807
#             218 NaN NaN NaN NaN NaN NaN NaN 1                         218
#             158 NaN NaN NaN NaN NaN NaN NaN 1                         158
#             66  NaN NaN NaN NaN NaN NaN NaN 1                          66
#
#                                                frame.comment  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1            NaN
#                                             1            NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1            NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1            NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1            NaN
# ...                                                      ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1            NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1            NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1            NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1            NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1            NaN
#
#                                                frame.comment.expert  ...  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
#                                             1                   NaN  ...
#             815 NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
#             219 NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
#             562 NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
# ...                                                             ...  ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
#             807 NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
#             218 NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
#             158 NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                   NaN  ...
#
#                                                tcp.time_delta  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1    0.000000e+00
#                                             1    8.120960e-04
#             815 NaN NaN NaN NaN NaN NaN NaN 1    2.486321e+01
#             219 NaN NaN NaN NaN NaN NaN NaN 1    2.203565e-03
#             562 NaN NaN NaN NaN NaN NaN NaN 1    2.870000e-07
# ...                                                       ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1    8.649190e-04
#             807 NaN NaN NaN NaN NaN NaN NaN 1    1.772775e+01
#             218 NaN NaN NaN NaN NaN NaN NaN 1    2.755838e-03
#             158 NaN NaN NaN NaN NaN NaN NaN 1    3.753690e-04
#             66  NaN NaN NaN NaN NaN NaN NaN 1    2.114770e-04
#
#                                                tcp.analysis.bytes_in_flight.1  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                             NaN
#                                             1                             NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                             NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                           153.0
#             562 NaN NaN NaN NaN NaN NaN NaN 1                           649.0
# ...                                                                       ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                             NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                           741.0
#             218 NaN NaN NaN NaN NaN NaN NaN 1                           152.0
#             158 NaN NaN NaN NaN NaN NaN NaN 1                           244.0
#             66  NaN NaN NaN NaN NaN NaN NaN 1                             NaN
#
#                                                tcp.analysis.push_bytes_sent.1  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                             NaN
#                                             1                             NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                             NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                           153.0
#             562 NaN NaN NaN NaN NaN NaN NaN 1                           496.0
# ...                                                                       ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                             NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                           741.0
#             218 NaN NaN NaN NaN NaN NaN NaN 1                           152.0
#             158 NaN NaN NaN NaN NaN NaN NaN 1                            92.0
#             66  NaN NaN NaN NaN NaN NaN NaN 1                             NaN
#
#                                                                                      tcp.payload  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                                                NaN
#                                             1                                                NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1  504f5354202f626561636f6e20485454502f312e310d0a...
#             219 NaN NaN NaN NaN NaN NaN NaN 1  485454502f312e3120323030204f4b0d0a436f6e74656e...
#             562 NaN NaN NaN NaN NaN NaN NaN 1  65794a77595863694f6941695a6e4a3564484e36496977...
# ...                                                                                          ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                                                NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1  504f5354202f626561636f6e20485454502f312e310d0a...
#             218 NaN NaN NaN NaN NaN NaN NaN 1  485454502f312e3120323030204f4b0d0a436f6e74656e...
#             158 NaN NaN NaN NaN NaN NaN NaN 1  65794a77595863694f694169596d4a35596d5675496977...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                                                NaN
#
#                                                tls.record.content_type  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                      NaN
#                                             1                      NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                      NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                      NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1                      NaN
# ...                                                                ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                      NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                      NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1                      NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1                      NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1                      NaN
#
#                                                tls.record.version  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#                                             1                 NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
# ...                                                           ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#
#                                                tls.record.length  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                NaN
#                                             1                NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1                NaN
# ...                                                          ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1                NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1                NaN
#
#                                                tls.record.length.1  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                  NaN
#                                             1                  NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                  NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                  NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1                  NaN
# ...                                                            ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                  NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                  NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1                  NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1                  NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1                  NaN
#
#                                                tls.app_data  \
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1           NaN
#                                             1           NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1           NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1           NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1           NaN
# ...                                                     ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1           NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1           NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1           NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1           NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1           NaN
#
#                                                tls.app_data_proto
# NaN NaN NaN 66  NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#                                             1                 NaN
#             815 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             219 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             562 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
# ...                                                           ...
#             66  NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             807 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             218 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             158 NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#             66  NaN NaN NaN NaN NaN NaN NaN 1                 NaN
#
# [10032 rows x 188 columns]

# %% [markdown]
# ### Assigning clean and malicious labels

# %%
clean['label'] = 0
malicious['label'] = 1

# %%
clean.shape,malicious.shape
# Out:
# ((115955, 189), (10032, 189))

# %%
traffic = pd.concat([clean, malicious],ignore_index=True)

# %%
traffic
# Out:
#         frame.bblog  frame.bblog.serial_nr  frame.bblog.ticks  frame.cap_len  \
# 0               NaN                      0                NaN            NaN
# 1               NaN                      0                NaN            NaN
# 2               NaN                      0                NaN            NaN
# 3               NaN                      0                NaN            NaN
# 4               NaN                      0                NaN            NaN
# ...             ...                    ...                ...            ...
# 125982          NaN                      0                NaN            NaN
# 125983          NaN                      0                NaN            NaN
# 125984          NaN                      0                NaN            NaN
# 125985          NaN                      0                NaN            NaN
# 125986          NaN                      0                NaN            NaN
#
#         frame.cb_copy frame.cb_pen  frame.coloring_rule.name  \
# 0                   0         eth0                       NaN
# 1                   0         eth0                       NaN
# 2                   0         eth0                       NaN
# 3                   0         eth0                       NaN
# 4                   0         eth0                       NaN
# ...               ...          ...                       ...
# 125982              0         eth0                       NaN
# 125983              0         eth0                       NaN
# 125984              0         eth0                       NaN
# 125985              0         eth0                       NaN
# 125986              0         eth0                       NaN
#
#         frame.coloring_rule.string  frame.comment  frame.comment.expert  ...  \
# 0                              100            NaN                   NaN  ...
# 1                              100            NaN                   NaN  ...
# 2                               93            NaN                   NaN  ...
# 3                               60            NaN                   NaN  ...
# 4                               60            NaN                   NaN  ...
# ...                            ...            ...                   ...  ...
# 125982                          66            NaN                   NaN  ...
# 125983                         807            NaN                   NaN  ...
# 125984                         218            NaN                   NaN  ...
# 125985                         158            NaN                   NaN  ...
# 125986                          66            NaN                   NaN  ...
#
#         tcp.analysis.bytes_in_flight.1  tcp.analysis.push_bytes_sent.1  \
# 0                                 46.0                            46.0
# 1                                 46.0                            46.0
# 2                                 39.0                            39.0
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
# ...                                ...                             ...
# 125982                             NaN                             NaN
# 125983                           741.0                           741.0
# 125984                           152.0                           152.0
# 125985                           244.0                            92.0
# 125986                             NaN                             NaN
#
#                                               tcp.payload  \
# 0       17030300290000000000000007192cd5db0079c03356c5...
# 1       17030300290000000000000003dab9762f4a8fac091d2b...
# 2       1703030022c29ebde652d235f4da8fa1971a7e99e13ab3...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 125982                                                NaN
# 125983  504f5354202f626561636f6e20485454502f312e310d0a...
# 125984  485454502f312e3120323030204f4b0d0a436f6e74656e...
# 125985  65794a77595863694f694169596d4a35596d5675496977...
# 125986                                                NaN
#
#         tls.record.content_type  tls.record.version  tls.record.length  \
# 0                          23.0              0x0303                NaN
# 1                          23.0              0x0303                NaN
# 2                          23.0              0x0303                NaN
# 3                           NaN                 NaN                NaN
# 4                           NaN                 NaN                NaN
# ...                         ...                 ...                ...
# 125982                      NaN                 NaN                NaN
# 125983                      NaN                 NaN                NaN
# 125984                      NaN                 NaN                NaN
# 125985                      NaN                 NaN                NaN
# 125986                      NaN                 NaN                NaN
#
#         tls.record.length.1  \
# 0                      41.0
# 1                      41.0
# 2                      34.0
# 3                       NaN
# 4                       NaN
# ...                     ...
# 125982                  NaN
# 125983                  NaN
# 125984                  NaN
# 125985                  NaN
# 125986                  NaN
#
#                                              tls.app_data  \
# 0       0000000000000007192cd5db0079c03356c57736854de3...
# 1       0000000000000003dab9762f4a8fac091d2b109a3b6238...
# 2       c29ebde652d235f4da8fa1971a7e99e13ab34f1769fc25...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 125982                                                NaN
# 125983                                                NaN
# 125984                                                NaN
# 125985                                                NaN
# 125986                                                NaN
#
#                  tls.app_data_proto  label
# 0       Hypertext Transfer Protocol      0
# 1       Hypertext Transfer Protocol      0
# 2       Hypertext Transfer Protocol      0
# 3                               NaN      0
# 4                               NaN      0
# ...                             ...    ...
# 125982                          NaN      1
# 125983                          NaN      1
# 125984                          NaN      1
# 125985                          NaN      1
# 125986                          NaN      1
#
# [125987 rows x 189 columns]

# %%
data  = traffic

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### dropping features with more than 80% null values

# %%
data.isna().sum()
# Out:
# frame.bblog              125987
# frame.bblog.serial_nr         0
# frame.bblog.ticks        125987
# frame.cap_len            125987
# frame.cb_copy                 0
#                           ...
# tls.record.length        120291
# tls.record.length.1      105384
# tls.app_data             105293
# tls.app_data_proto       104253
# label                         0
# Length: 189, dtype: int64

# %%
limitPer = len(data) * .80
yourdf = data.dropna(thresh=limitPer, axis=1)

# %%
yourdf.isna().sum()
# Out:
# frame.bblog.serial_nr            0
# frame.cb_copy                    0
# frame.cb_pen                     0
# frame.coloring_rule.string       0
# frame.drop_count                 0
#                               ...
# ip.ttl                        2191
# ip.version                    2688
# ip.id                         2688
# ip.len                        2688
# label                            0
# Length: 66, dtype: int64

# %%
null_counts = yourdf.isnull().sum()
null_counts[null_counts > 0]
# Out:
# frame.time_invalid            1242
# eth.addr                      1242
# eth.addr.oui                   616
# eth.addr.oui_resolved         1242
# eth.addr_resolved             1858
# eth.dst                       1858
# eth.dst.ig                     616
# eth.dst_resolved              1858
# eth.fcs                       1858
# eth.invalid_lentype.expert     616
# eth.padding                   1242
# eth.padding_bad               1242
# eth.src.ig                    1858
# eth.src.oui                   1230
# eth.src_not_group             1361
# eth.trailer                   1858
# eth.type                      2060
# ip.addr                       2060
# ip.checksum                   2688
# ip.checksum.status            2688
# ip.dsfield                    2191
# ip.dsfield.dscp               2191
# ip.dsfield.ecn                2688
# ip.dst                        2060
# ip.dst_host                   2060
# ip.flags                      1563
# ip.flags.df                   2688
# ip.flags.mf                   2191
# ip.flags.rb                   2688
# ip.frag_offset                2688
# ip.src                        1552
# ip.hdr_len                    1563
# ip.proto                      2191
# ip.ttl                        2191
# ip.version                    2688
# ip.id                         2688
# ip.len                        2688
# dtype: int64

# %%
null_counts
# Out:
# frame.bblog.serial_nr            0
# frame.cb_copy                    0
# frame.cb_pen                     0
# frame.coloring_rule.string       0
# frame.drop_count                 0
#                               ...
# ip.ttl                        2191
# ip.version                    2688
# ip.id                         2688
# ip.len                        2688
# label                            0
# Length: 66, dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
list(yourdf.select_dtypes(['object']).columns)
# Out:
# ['frame.cb_pen',
#  'frame.packet_flags_packet_too_short_error',
#  'frame.packet_flags_reserved',
#  'frame.packet_flags_start_frame_delimiter_error',
#  'frame.time',
#  'frame.time_delta',
#  'frame.time_invalid',
#  'frame.time_relative',
#  'frame.verdict',
#  'frame.verdict.ebpf_tc',
#  'frame.verdict.ebpf_xdp',
#  'frame.verdict.hw',
#  'frame.verdict.unknown',
#  'eth.addr.oui',
#  'eth.addr.oui_resolved',
#  'eth.addr_resolved',
#  'eth.dst',
#  'eth.dst.ig',
#  'eth.invalid_lentype.expert',
#  'eth.len',
#  'eth.padding',
#  'eth.padding_bad',
#  'eth.src',
#  'eth.src.lg',
#  'eth.src.oui',
#  'eth.src_not_group',
#  'eth.trailer',
#  'eth.type',
#  'ip.addr',
#  'ip.checksum',
#  'ip.dsfield',
#  'ip.dsfield.dscp',
#  'ip.dst',
#  'ip.dst_host',
#  'ip.flags',
#  'ip.src',
#  'ip.proto',
#  'ip.id']

# %% [markdown]
# ### Replacing null values of Numeric Features with mean and Object features with Mode.

# %%
# Loop through each column in the dataframe
for col in yourdf.columns:
    # Check if column contains numeric values
    if np.issubdtype(yourdf[col].dtype, np.number):
        # Replace null values with mean of column
        yourdf[col].fillna(yourdf[col].mean(), inplace=True)
    else:
        # Replace null values with mode of column
        yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# Out:
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mode()[0], inplace=True)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/1293574417.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col].fillna(yourdf[col].mean(), inplace=True)

# %%
yourdf
# Out:
#         frame.bblog.serial_nr  frame.cb_copy frame.cb_pen  \
# 0                           0              0         eth0
# 1                           0              0         eth0
# 2                           0              0         eth0
# 3                           0              0         eth0
# 4                           0              0         eth0
# ...                       ...            ...          ...
# 125982                      0              0         eth0
# 125983                      0              0         eth0
# 125984                      0              0         eth0
# 125985                      0              0         eth0
# 125986                      0              0         eth0
#
#         frame.coloring_rule.string  frame.drop_count  frame.file_off  \
# 0                              100                 0               1
# 1                              100                 0               2
# 2                               93                 0               3
# 3                               60                 0               4
# 4                               60                 0               5
# ...                            ...               ...             ...
# 125982                          66                 0           10105
# 125983                         807                 0           10106
# 125984                         218                 0           10107
# 125985                         158                 0           10108
# 125986                          66                 0           10109
#
#         frame.ignored  frame.packet_flags_packet_too_short_error  \
# 0                 0.0                   eth:ethertype:ip:tcp:tls
# 1                 0.0                   eth:ethertype:ip:tcp:tls
# 2                 0.0                   eth:ethertype:ip:tcp:tls
# 3                 0.0                       eth:ethertype:ip:tcp
# 4                 0.0                       eth:ethertype:ip:tcp
# ...               ...                                        ...
# 125982            0.0                       eth:ethertype:ip:tcp
# 125983            0.0             eth:ethertype:ip:tcp:http:data
# 125984            0.0                       eth:ethertype:ip:tcp
# 125985            0.0  eth:ethertype:ip:tcp:http:data-text-lines
# 125986            0.0                       eth:ethertype:ip:tcp
#
#         frame.packet_flags_reception_type frame.packet_flags_reserved  ...  \
# 0                                       1                      Feb 27  ...
# 1                                       1                      Feb 27  ...
# 2                                       1                      Feb 27  ...
# 3                                       1                      Feb 27  ...
# 4                                       1                      Feb 27  ...
# ...                                   ...                         ...  ...
# 125982                                  1                      Mar  7  ...
# 125983                                  1                      Mar  7  ...
# 125984                                  1                      Mar  7  ...
# 125985                                  1                      Mar  7  ...
# 125986                                  1                      Mar  7  ...
#
#        ip.flags.rb  ip.frag_offset           ip.src  ip.hdr_len  ip.proto  \
# 0              0.0             0.0  192.168.126.142        20.0       6.0
# 1              0.0             0.0  192.168.126.142        20.0       6.0
# 2              0.0             0.0  192.168.126.142        20.0       6.0
# 3              0.0             0.0     35.241.9.150        20.0       6.0
# 4              0.0             0.0   34.160.144.191        20.0       6.0
# ...            ...             ...              ...         ...       ...
# 125982         0.0             0.0  192.168.126.139        20.0         6
# 125983         0.0             0.0  192.168.126.142        20.0         6
# 125984         0.0             0.0  192.168.126.139        20.0         6
# 125985         0.0             0.0  192.168.126.139        20.0         6
# 125986         0.0             0.0  192.168.126.142        20.0         6
#
#        ip.ttl ip.version   ip.id  ip.len label
# 0        64.0        4.0  0xcd9f    86.0     0
# 1        64.0        4.0  0xc8c7    86.0     0
# 2        64.0        4.0  0x17cf    79.0     0
# 3       128.0        4.0  0x3978    40.0     0
# 4       128.0        4.0  0x3979    40.0     0
# ...       ...        ...     ...     ...   ...
# 125982   64.0        4.0  0x2004    52.0     1
# 125983   64.0        4.0  0x70ea   793.0     1
# 125984   64.0        4.0  0x2005   204.0     1
# 125985   64.0        4.0  0x2006   144.0     1
# 125986   64.0        4.0  0x70eb    52.0     1
#
# [125987 rows x 66 columns]

# %% [markdown]
# ### encoding Object features as categorical numerical features

# %%
for col in yourdf.columns:
    # Check if column contains object values
    if yourdf[col].dtype == 'object':
        # Factorize the column
        yourdf[col] = pd.factorize(yourdf[col])[0]
# Out:
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_99569/606315440.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yourdf[col] = pd.factorize(yourdf[col])[0]

# %% [markdown]
# # Machine Learning

# %%
data = yourdf

# %%
X = data.drop("label", axis=1)
y = data["label"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,shuffle=True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
random_forest_classifier = RandomForestClassifier(n_estimators=10, random_state=42)
random_forest_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %%
y_pred = random_forest_classifier.predict(X)
print('Model accuracy score with 100 decision-trees : {0:0.4f}'. format(accuracy_score(y, y_pred)*100))
# Out:
# Model accuracy score with 100 decision-trees : 100.0000

# %%
data.to_csv("/Users/asadtariq/Downloads/test.csv")

# %% [markdown]
# # New Feature Selection

# %%
importances = random_forest_classifier.feature_importances_

# Get feature names
feature_names = X.columns

# Create a dataframe of feature importances
feature_importances = pd.DataFrame({'feature': feature_names, 'importance': importances})

# Sort the dataframe by feature importance in descending order
important_features = feature_importances[feature_importances['importance'] > 0]

# Print important features
print(important_features)
# Out:
#                                            feature  importance
# 9                      frame.packet_flags_reserved    0.056421
# 10  frame.packet_flags_start_frame_delimiter_error    0.203991
# 13  frame.packet_flags_wrong_inter_frame_gap_error    0.195020
# 15                                      frame.time    0.043579
# 16                                frame.time_delta    0.105026
# 24                                frame.verdict.hw    0.052370
# 25                           frame.verdict.unknown    0.047938
# 31                                      eth.dst.ig    0.046711
# 36                                     eth.padding    0.052464
# 42                               eth.src_not_group    0.052610
# 45                                         ip.addr    0.090581
# 58                                          ip.src    0.053289

# %% [markdown]
# # Metrics Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, cohen_kappa_score

acc = accuracy_score(y, y_pred)
prec = precision_score(y, y_pred)
rec = recall_score(y, y_pred)
f1 = f1_score(y, y_pred)
auc_roc = roc_auc_score(y, random_forest_classifier.predict_proba(X)[:, 1])
kappa = cohen_kappa_score(y, y_pred)

print("Accuracy score:", acc *100)
print("Precision score:", prec*100)
print("Recall score:", rec*100)
print("F1 score:", f1*100)
print("AUC-ROC score:", auc_roc*100)
print("Cohen's kappa score:", kappa*100)
# Out:
# Accuracy score: 100.0
# Precision score: 100.0
# Recall score: 100.0
# F1 score: 100.0
# AUC-ROC score: 100.0
# Cohen's kappa score: 100.0
