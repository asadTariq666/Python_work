# %%
#Extracting the data from zip file and storing as a pandas dataframe
from zipfile import ZipFile
import pandas as pd
#import xlsxwriter
import numpy as np
import matplotlib.pyplot as plt

# %%
with ZipFile('data.zip', 'r') as my_zip:
    my_zip.extract('data/Canada.xlsx')
x1 = pd.ExcelFile('data/Canada.xlsx')
sheet = x1.sheet_names
#Creating 2 dataframes for the 2 sheets
df1 = pd.read_excel(x1, sheet_name = 'Regions by Citizenship')
df2 = pd.read_excel(x1, sheet_name = 'Canada by Citizenship')

df1.head(30)
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                      United Nations         NaN
# 4                                 Population Division         NaN
# 5           Department of Economic and Social Affairs         NaN
# 6                                                 NaN         NaN
# 7   International Migration Flows to and from Sele...         NaN
# 8                                                 NaN         NaN
# 9                            POP/DB/MIG/Flow/Rev.2015         NaN
# 10  December 2015 - Copyright © 2015 by United Nat...         NaN
# 11  Suggested citation: United Nations, Department...         NaN
# 12   International Migration Flows to and from Sel...         NaN
# ...

# %%
df2.head(10)
# Out:
#   Classification  Unnamed: 1   Origin/Destination Major area  \
# 0           Type    Coverage               OdName       AREA
# 1     Immigrants  Foreigners          Afghanistan        935
# 2     Immigrants  Foreigners              Albania        908
# 3     Immigrants  Foreigners              Algeria        903
# 4     Immigrants  Foreigners       American Samoa        909
# 5     Immigrants  Foreigners              Andorra        908
# 6     Immigrants  Foreigners               Angola        903
# 7     Immigrants  Foreigners  Antigua and Barbuda        904
# 8     Immigrants  Foreigners            Argentina        904
# 9     Immigrants  Foreigners              Armenia        935
#
#                         Unnamed: 4 Region       Unnamed: 6 Development region  \
# 0                         AreaName    REG          RegName                DEV
# 1                             Asia   5501    Southern Asia                902
# ...

# %%
#Q1
#check for how many missing values there are and use a method to solve them
#slicing rows remove the irrelivant NaN info
#df1_sliced = df1.loc[19:]
#df1_sliced
#df1_sliced.isnull().sum().sum()
#df1_new_slice = df1_sliced.drop(['Unnamed: 37'], axis = 1)
'''
Figure out method so solve column 37
'''
df1_sliced = df1.loc[19:]
df1_sliced
# Out:
#     Unnamed: 0  Unnamed: 1                             Unnamed: 2  \
# 19        Type    Coverage                               AreaName
# 20  Immigrants    Citizens                       Northern America
# 21  Immigrants  Foreigners                                 Africa
# 22  Immigrants  Foreigners                                 Africa
# 23  Immigrants  Foreigners                                 Africa
# 24  Immigrants  Foreigners                                 Africa
# 25  Immigrants  Foreigners                                 Africa
# 26  Immigrants  Foreigners                           Africa Total
# 27  Immigrants  Foreigners                                   Asia
# 28  Immigrants  Foreigners                                   Asia
# 29  Immigrants  Foreigners                                   Asia
# 30  Immigrants  Foreigners                                   Asia
# 31  Immigrants  Foreigners                                   Asia
# ...

# %%
#df2.isnull().values.any()
#checking the number of NaN values in the other sheet data
df2.isnull().sum().sum()
# Out:
# 0

# %%
#df1_new_slice.isnull().sum().sum()
#Replacing .. values with 0
df1_dot_replaced = df1_sliced.replace('..', 0)

# %%
#Replacing NaN values in sheet 1 with 0
#df1.fillna(0)
#df1_sliced.isnull().sum().sum()
df1_dot_replaced.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 1      0
# Unnamed: 2      0
# Unnamed: 3      5
# Unnamed: 4      0
# Unnamed: 5      0
# Unnamed: 6      0
# Unnamed: 7      0
# Unnamed: 8      0
# Unnamed: 9      0
# Unnamed: 10     0
# Unnamed: 11     0
# Unnamed: 12     0
# Unnamed: 13     0
# Unnamed: 14     0
# Unnamed: 15     0
# Unnamed: 16     0
# Unnamed: 17     0
# Unnamed: 18     0
# Unnamed: 19     0
# Unnamed: 20     0
# Unnamed: 21     0
# Unnamed: 22     0
# Unnamed: 23     0
# Unnamed: 24     0
# Unnamed: 25     0
# Unnamed: 26     0
# Unnamed: 27     0
# Unnamed: 28     0
# Unnamed: 29     0
# Unnamed: 30     0
# Unnamed: 31     0
# Unnamed: 32     0
# Unnamed: 33     0
# Unnamed: 34     0
# Unnamed: 35     0
# Unnamed: 36     0
# Unnamed: 37    29
# dtype: int64

# %%
#df['avg'] = df.iloc[:,0:2].mean(axis=1)
'''
df1_nan_sorted = df1_dot_replaced.fillna(df1_dot_replaced.mean(axis=1))
df1_nan_sorted
'''
df1_dot_replaced['Unnamed: 37'] = df1_dot_replaced.iloc[:,4:36].mean(axis = 1)
df1_dot_replaced
# Out:
#     Unnamed: 0  Unnamed: 1                             Unnamed: 2  \
# 19        Type    Coverage                               AreaName
# 20  Immigrants    Citizens                       Northern America
# 21  Immigrants  Foreigners                                 Africa
# 22  Immigrants  Foreigners                                 Africa
# 23  Immigrants  Foreigners                                 Africa
# 24  Immigrants  Foreigners                                 Africa
# 25  Immigrants  Foreigners                                 Africa
# 26  Immigrants  Foreigners                           Africa Total
# 27  Immigrants  Foreigners                                   Asia
# 28  Immigrants  Foreigners                                   Asia
# 29  Immigrants  Foreigners                                   Asia
# 30  Immigrants  Foreigners                                   Asia
# 31  Immigrants  Foreigners                                   Asia
# ...

# %%
#df1_dot_replaced.round(0)
pd.options.display.float_format = '{:,.0f}'.format

df1_dot_replaced.iloc[0, df1_dot_replaced.columns.get_loc('Unnamed: 37')] = 2013
df1_dot_replaced.head(10)
# Out:
#     Unnamed: 0  Unnamed: 1        Unnamed: 2        Unnamed: 3  Unnamed: 4  \
# 19        Type    Coverage          AreaName           RegName        1980
# 20  Immigrants    Citizens  Northern America  Northern America           0
# 21  Immigrants  Foreigners            Africa    Eastern Africa        1471
# 22  Immigrants  Foreigners            Africa     Middle Africa          33
# 23  Immigrants  Foreigners            Africa   Northern Africa        1100
# 24  Immigrants  Foreigners            Africa   Southern Africa        1041
# 25  Immigrants  Foreigners            Africa    Western Africa         306
# 26  Immigrants  Foreigners      Africa Total               NaN        3951
# 27  Immigrants  Foreigners              Asia      Central Asia           0
# 28  Immigrants  Foreigners              Asia      Eastern Asia        6836
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 19        1981        1982        1983        1984        1985  ...
# ...

# %%
#Q2
df2["total_before 2000"] = df2.iloc[:,9:28].sum(axis = 1)
df2["total_after 2000"] = df2.iloc[:,28: 42].sum(axis = 1)
df2.iat[0,43] = 0
df2.iat[0,44] = 0
df2.head(10)
# Out:
# /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Classification  Unnamed: 1   Origin/Destination Major area  \
# 0           Type    Coverage               OdName       AREA
# 1     Immigrants  Foreigners          Afghanistan        935
# 2     Immigrants  Foreigners              Albania        908
# 3     Immigrants  Foreigners              Algeria        903
# 4     Immigrants  Foreigners       American Samoa        909
# 5     Immigrants  Foreigners              Andorra        908
# 6     Immigrants  Foreigners               Angola        903
# 7     Immigrants  Foreigners  Antigua and Barbuda        904
# 8     Immigrants  Foreigners            Argentina        904
# ...

# %%
df1_dot_replaced["total_before 2000"] = df1_dot_replaced.iloc[:,4:24].sum(axis = 1)
df1_dot_replaced["total_after 2000"] = df1_dot_replaced.iloc[:,24: 37].sum(axis = 1)
df1_dot_replaced.iat[0,38] = 0
df1_dot_replaced.iat[0,39] = 0
df1_dot_replaced.head(10)
# Out:
#     Unnamed: 0  Unnamed: 1        Unnamed: 2        Unnamed: 3  Unnamed: 4  \
# 19        Type    Coverage          AreaName           RegName        1980
# 20  Immigrants    Citizens  Northern America  Northern America           0
# 21  Immigrants  Foreigners            Africa    Eastern Africa        1471
# 22  Immigrants  Foreigners            Africa     Middle Africa          33
# 23  Immigrants  Foreigners            Africa   Northern Africa        1100
# 24  Immigrants  Foreigners            Africa   Southern Africa        1041
# 25  Immigrants  Foreigners            Africa    Western Africa         306
# 26  Immigrants  Foreigners      Africa Total               NaN        3951
# 27  Immigrants  Foreigners              Asia      Central Asia           0
# 28  Immigrants  Foreigners              Asia      Eastern Asia        6836
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 19        1981        1982        1983        1984        1985  ...
# ...

# %%
df1_dot_replaced
# Out:
#     Unnamed: 0  Unnamed: 1                             Unnamed: 2  \
# 19        Type    Coverage                               AreaName
# 20  Immigrants    Citizens                       Northern America
# 21  Immigrants  Foreigners                                 Africa
# 22  Immigrants  Foreigners                                 Africa
# 23  Immigrants  Foreigners                                 Africa
# 24  Immigrants  Foreigners                                 Africa
# 25  Immigrants  Foreigners                                 Africa
# 26  Immigrants  Foreigners                           Africa Total
# 27  Immigrants  Foreigners                                   Asia
# 28  Immigrants  Foreigners                                   Asia
# 29  Immigrants  Foreigners                                   Asia
# 30  Immigrants  Foreigners                                   Asia
# 31  Immigrants  Foreigners                                   Asia
# ...

# %%
#Q3

import seaborn as sns
import numpy as np
import matplotlib as plt
import timeit

get_years_row = df2.loc[df2['Origin/Destination'] == "OdName"]
get_canada_row = df2.loc[df2['Origin/Destination'] == "Canada"]
get_china_row = df2.loc[df2['Origin/Destination'] == "China"]
get_india_row = df2.loc[df2['Origin/Destination'] == "India"]
get_japan_row = df2.loc[df2['Origin/Destination'] == "Japan"]

frames = [get_years_row, get_canada_row, get_china_row, get_india_row, get_japan_row]
combined_frames_q2 = pd.concat(frames)

combined_frames_q2.drop(combined_frames_q2.iloc[:, 0:2], inplace = True, axis = 1)
combined_frames_q2.drop(combined_frames_q2.iloc[:, 1:7], inplace = True, axis = 1)
final_combined_frames = combined_frames_q2.drop(['total_before 2000', 'total_after 2000'], axis = 1)

new_table_transposed = final_combined_frames.T
renamed_new_columns = new_table_transposed.rename(columns = {
    0: 'Years',
    33: 'Canada',
    37:'China',
    80:'India',
    88:'Japan'
    })

renamed_new_columns.head(5)
table_head_dropped = renamed_new_columns.drop(renamed_new_columns.index[0])
table_head_dropped

#sns.relplot(x = 'Years', y = ['Canada', 'China', 'India', 'Japan'], data = table_head_dropped)
# Out:
#             Years Canada  China  India Japan
# Unnamed: 9   1980      0   5123   8880   701
# Unnamed: 10  1981      0   6682   8670   756
# Unnamed: 11  1982      0   3308   8147   598
# Unnamed: 12  1983      0   1863   7338   309
# Unnamed: 13  1984      0   1527   5704   246
# Unnamed: 14  1985      0   1816   4211   198
# Unnamed: 15  1986      0   1960   7150   248
# Unnamed: 16  1987      0   2643  10189   422
# Unnamed: 17  1988      0   2758  11522   324
# Unnamed: 18  1989      0   4323  10343   494
# Unnamed: 19  1990      3   8076  12041   379
# Unnamed: 20  1991      3  14255  13734   506
# Unnamed: 21  1992      4  10846  13673   605
# Unnamed: 22  1993      3   9817  21496   907
# Unnamed: 23  1994      1  13128  18620   956
# Unnamed: 24  1995      1  14398  18489   826
# Unnamed: 25  1996      1  19415  23859   994
# Unnamed: 26  1997      0  20475  22268   924
# Unnamed: 27  1998      0  21049  17241   897
# Unnamed: 28  1999      0  30069  18974  1083
# ...

# %%
table_head_dropped.reset_index(drop=True, inplace=True)

# %%
table_head_dropped.head()
# Out:
#   Years Canada China India Japan
# 0  1980      0  5123  8880   701
# 1  1981      0  6682  8670   756
# 2  1982      0  3308  8147   598
# 3  1983      0  1863  7338   309
# 4  1984      0  1527  5704   246

# %%
table_head_dropped_melted=(table_head_dropped.melt('Years', 
             var_name='Countries', 
             value_name='Value'))
table_head_dropped_melted.head()
# Out:
#   Years Countries Value
# 0  1980    Canada     0
# 1  1981    Canada     0
# 2  1982    Canada     0
# 3  1983    Canada     0
# 4  1984    Canada     0

# %%
#plotting
sns.set(rc={'figure.figsize':(25,10)})
fg = sns.relplot(x = 'Years', y = 'Value',
            kind = 'line', hue= 'Countries',
            data = table_head_dropped_melted, height=10,aspect=1.5)
