# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.13.0-py2.py3-none-any.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 5.0 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (2.8.2)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (3.10.0.2)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-9.0.0-cp37-cp37m-macosx_10_13_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 18.5 MB/s eta 0:00:010:00:02
# Collecting altair>=3.2.0
#   Using cached altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: numpy in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (1.21.2)
# Collecting rich>=10.11.0
#   Downloading rich-12.5.1-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 27.4 MB/s eta 0:00:01
# Requirement already satisfied: cachetools>=4.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (5.0.0)
# Requirement already satisfied: click>=7.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (8.1.2)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting tzlocal>=1.1
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.21.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (1.3.4)
# Requirement already satisfied: tornado>=5.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (6.1)
# Requirement already satisfied: requests>=2.4 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (2.27.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (4.8.2)
# Requirement already satisfied: protobuf!=3.20.2,<4,>=3.12 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (3.20.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (8.4.0)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0b3-py2.py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 7.1 MB/s eta 0:00:01     |██████████████████████████████▍ | 4.5 MB 7.1 MB/s eta 0:00:01
# Collecting gitpython!=3.1.19
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Collecting toml
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Requirement already satisfied: packaging>=14.1 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from streamlit) (21.3)
# Collecting pympler>=0.9
#   Using cached Pympler-1.0.1-py3-none-any.whl (164 kB)
# Requirement already satisfied: jinja2 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (3.0.2)
# Collecting toolz
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 6.8 MB/s  eta 0:00:01
# Requirement already satisfied: entrypoints in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from importlib-metadata>=1.4->streamlit) (3.6.0)
# Requirement already satisfied: six>=1.11.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: setuptools in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (58.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from packaging>=14.1->streamlit) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from requests>=2.4->streamlit) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from requests>=2.4->streamlit) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from requests>=2.4->streamlit) (3.3)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 11.3 MB/s eta 0:00:01
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from rich>=10.11.0->streamlit) (2.10.0)
# Collecting typing-extensions>=3.10.0.0
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting backports.zoneinfo
#   Using cached backports.zoneinfo-0.2.1-cp37-cp37m-macosx_10_14_x86_64.whl (35 kB)
# Collecting pytz-deprecation-shim
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages (from validators>=0.2->streamlit) (5.1.0)
# Collecting tzdata
#   Downloading tzdata-2022.2-py2.py3-none-any.whl (336 kB)
#      |████████████████████████████████| 336 kB 31.2 MB/s eta 0:00:01
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19583 sha256=5cd465f38517d35630b103550fba5b82ffb8e825d43ffdd07acc1dd874c662ed
#   Stored in directory: /Users/asadtariq/Library/Caches/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# Installing collected packages: typing-extensions, tzdata, smmap, backports.zoneinfo, toolz, pytz-deprecation-shim, gitdb, commonmark, validators, tzlocal, toml, semver, rich, pympler, pydeck, pyarrow, gitpython, blinker, altair, streamlit
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
# Successfully installed altair-4.2.0 backports.zoneinfo-0.2.1 blinker-1.5 commonmark-0.9.1 gitdb-4.0.9 gitpython-3.1.27 pyarrow-9.0.0 pydeck-0.8.0b3 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-12.5.1 semver-2.13.0 smmap-5.0.0 streamlit-1.13.0 toml-0.10.2 toolz-0.12.0 typing-extensions-4.3.0 tzdata-2022.2 tzlocal-4.2 validators-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import streamlit as st

st.title("Hello world!")

uploaded_file = st.file_uploader("Choose a file")
if uploaded_file is not None:
  df = pd.read_csv(uploaded_file)
  st.write(df)

  # Add some matplotlib code !
  fig, ax = plt.subplots()
  df.hist(
    bins=8,
    column="Age",
    grid=False,
    figsize=(8, 8),
    color="#86bf91",
    zorder=2,
    rwidth=0.9,
    ax=ax,
  )
  st.write(fig)
# Out:
# 2022-09-22 19:54:37.691
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/asadtariq/opt/anaconda3/envs/pythonProject/lib/python3.7/site-packages/ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_10166/932755800.py in <module>
#      22     ax=ax,
#      23   )
# ---> 24 st.write(fig)
#
# NameError: name 'fig' is not defined

# %%
import time  # to simulate a real time data, time loop

import numpy as np  # np mean, np random
import pandas as pd  # read csv, df manipulation
import plotly.express as px  # interactive charts
import streamlit as st  # 🎈 data web app development

# %%
dataset_url = "https://raw.githubusercontent.com/Lexie88rus/bank-marketing-analysis/master/bank.csv"

# read csv from a URL
@st.experimental_memo
def get_data() -> pd.DataFrame:
    return pd.read_csv(dataset_url)

df = get_data()

# %%
df.head(
)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
st.set_page_config(
    page_title="Real-Time Data Science Dashboard",
    page_icon="✅",
    layout="wide",
)

# %%
# dashboard title
st.title("Real-Time / Live Data Science Dashboard")
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
# top-level filters
job_filter = st.selectbox("Select the Job", pd.unique(df["job"]))

# %%
# dataframe filter
df = df[df["job"] == job_filter]

# %%
# create three columns
kpi1, kpi2, kpi3 = st.columns(3)

# fill in those three columns with respective metrics or KPIs
kpi1.metric(
    label="Age ⏳",
    value=round(avg_age),
    delta=round(avg_age) - 10,
)

kpi2.metric(
    label="Married Count 💍",
    value=int(count_married),
    delta=-10 + count_married,
)

kpi3.metric(
    label="A/C Balance ＄",
    value=f"$ {round(balance,2)} ",
    delta=-round(balance / count_married) * 100,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_10166/1776603482.py in <module>
#       4 kpi1.metric(
#       5     label="Age ⏳",
# ----> 6     value=round(avg_age),
#       7     delta=round(avg_age) - 10,
#       8 )
#
# NameError: name 'avg_age' is not defined

# %%
import time  # to simulate a real time data, time loop

import numpy as np  # np mean, np random
import pandas as pd  # read csv, df manipulation
import plotly.express as px  # interactive charts
import streamlit as st  # 🎈 data web app development

st.set_page_config(
    page_title="Real-Time Data Science Dashboard",
    page_icon="✅",
    layout="wide",
)

# read csv from a github repo
dataset_url = "https://raw.githubusercontent.com/Lexie88rus/bank-marketing-analysis/master/bank.csv"

# read csv from a URL
@st.experimental_memo
def get_data() -> pd.DataFrame:
    return pd.read_csv(dataset_url)

df = get_data()

# dashboard title
st.title("Real-Time / Live Data Science Dashboard")

# top-level filters
job_filter = st.selectbox("Select the Job", pd.unique(df["job"]))

# creating a single-element container
placeholder = st.empty()

# dataframe filter
df = df[df["job"] == job_filter]

# near real-time / live feed simulation
for seconds in range(200):

    df["age_new"] = df["age"] * np.random.choice(range(1, 5))
    df["balance_new"] = df["balance"] * np.random.choice(range(1, 5))

    # creating KPIs
    avg_age = np.mean(df["age_new"])

    count_married = int(
        df[(df["marital"] == "married")]["marital"].count()
        + np.random.choice(range(1, 30))
    )

    balance = np.mean(df["balance_new"])

    with placeholder.container():

        # create three columns
        kpi1, kpi2, kpi3 = st.columns(3)

        # fill in those three columns with respective metrics or KPIs
        kpi1.metric(
            label="Age ⏳",
            value=round(avg_age),
            delta=round(avg_age) - 10,
        )
        
        kpi2.metric(
            label="Married Count 💍",
            value=int(count_married),
            delta=-10 + count_married,
        )
        
        kpi3.metric(
            label="A/C Balance ＄",
            value=f"$ {round(balance,2)} ",
            delta=-round(balance / count_married) * 100,
        )

        # create two columns for charts
        fig_col1, fig_col2 = st.columns(2)
        with fig_col1:
            st.markdown("### First Chart")
            fig = px.density_heatmap(
                data_frame=df, y="age_new", x="marital"
            )
            st.write(fig)
            
        with fig_col2:
            st.markdown("### Second Chart")
            fig2 = px.histogram(data_frame=df, x="age_new")
            st.write(fig2)

        st.markdown("### Detailed Data View")
        st.dataframe(df)
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/dk/9q84mn0j1nzfg85t9zx5d1480000gn/T/ipykernel_10166/3977273039.py in <module>
#      90         st.markdown("### Detailed Data View")
#      91         st.dataframe(df)
# ---> 92         time.sleep(1)
#      93
#
# KeyboardInterrupt:
